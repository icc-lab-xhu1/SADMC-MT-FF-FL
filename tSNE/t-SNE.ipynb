# %%
from openTSNE import TSNE
import numpy as np
from sklearn.model_selection import train_test_split
import utils

import matplotlib.pyplot as plt

# %%
classname = 'user.csv'
x_train = np.load("../Mul_Class_Data/" + classname + "_Xtrain.npy")
y_train = np.load("../Mul_Class_Data/" + classname + "_Ytrain.npy")
x_test = np.load("../Mul_Class_Data/" + classname + "_Xtest.npy")
y_test = np.load("../Mul_Class_Data/" + classname + "_Ytest.npy")
num_classes = y_test.shape[1]
length = x_train.shape[1]
###
y_test = np.argmax(y_test, axis=1)
y_train = np.argmax(y_train, axis=1)
x_train.shape,y_train.shape,x_test.shape,y_test.shape
# Out:
# ((3174, 36), (3174,), (1361, 36), (1361,))

# %%
tsne = TSNE(
    perplexity=30,
    metric="euclidean",
    n_jobs=8,
    random_state=36,
    verbose=True,
)

# %%
# %time 
embedding_train = tsne.fit(x_test)
# Out:
# CPU times: total: 0 ns
# Wall time: 1 ms
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=8, random_state=36, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.14 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=12.00, lr=113.42 for 250 iterations...
# Iteration   50, KL divergence 2.7540, 50 iterations in 0.0682 sec
# Iteration  100, KL divergence 2.7511, 50 iterations in 0.0748 sec
# Iteration  150, KL divergence 2.7438, 50 iterations in 0.0650 sec
# Iteration  200, KL divergence 2.7401, 50 iterations in 0.0640 sec
# Iteration  250, KL divergence 2.7377, 50 iterations in 0.0650 sec
#    --> Time elapsed: 0.34 seconds
# ===> Running optimization with exaggeration=1.00, lr=1361.00 for 500 iterations...
# Iteration   50, KL divergence 1.1797, 50 iterations in 0.0650 sec
# Iteration  100, KL divergence 1.0716, 50 iterations in 0.0653 sec
# Iteration  150, KL divergence 1.0306, 50 iterations in 0.0627 sec
# Iteration  200, KL divergence 1.0127, 50 iterations in 0.0620 sec
# Iteration  250, KL divergence 1.0032, 50 iterations in 0.0640 sec
# Iteration  300, KL divergence 0.9950, 50 iterations in 0.0660 sec
# Iteration  350, KL divergence 0.9902, 50 iterations in 0.0665 sec
# Iteration  400, KL divergence 0.9861, 50 iterations in 0.0670 sec
# Iteration  450, KL divergence 0.9833, 50 iterations in 0.0670 sec
# Iteration  500, KL divergence 0.9809, 50 iterations in 0.0645 sec
#    --> Time elapsed: 0.65 seconds

# %%
utils.plot(embedding_train, y_test)
